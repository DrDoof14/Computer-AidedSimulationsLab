# %%
from scipy.stats import binom

n = 50
p = 0.9

r = list(range(n + 1))
dist = binom.pmf(r, n, p)

import matplotlib.pyplot as plt

plt.bar(r, dist)
plt.show()

# %%
#but we have to perfrom log on the distro
